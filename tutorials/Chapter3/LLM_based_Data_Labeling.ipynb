# %% [markdown]
# ## Topic Classification and Item Similarity Labeling Using LLMs
#
# ** Objectives **
#
# - **Automated Labeling Tasks:** Use LLMs for topic classification and item similarity labeling.
#
# - **Multi-LLM Evaluation:** Assess agreement and alignment with human expectations using multiple LLM-as-a-judge models.
#
# - **Scalable Labeling:** Implement batch inference to efficiently process large-scale labeling tasks.
#
# #### Prerequisites
# - Python 3.8+ installed.
#
# - Libraries: transformers, openai, scikit-learn, numpy, pandas.
#
# - OpenAI API key for using GPT models.
#
# #### Step 1: Load and Prepare Data
#
# Load a dataset of news articles (e.g., df_combined with a summary_cleaned column containing article summaries).Ensure the dataset is clean and ready for processing.

# %%
import pandas as pd

# Load dataset
file_path = "./../Data/news-recommendation/news_summary.tsv"
item_df = pd.read_csv(file_path, sep="\t")
item_df = item_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
print(item_df.shape)
print(set(item_df['category'].tolist()))
item_df.head()

# %% [markdown]
# #### Step 3: Topic Classification Labeling Using Prompts
# - Create a list of predefined topics (e.g., health, technology, sports).
# - Design Prompt for Topic Classification
# - Classify all articles in the dataset and store the results.

# %%
import json
import re

import openai
import os
from openai import OpenAI
import yaml
import time

import logging
# Configure logging
logging.basicConfig(level=logging.DEBUG, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

import torch
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
from openai import OpenAI
from sklearn.neighbors import NearestNeighbors
import time

# Read the YAML file
with open('./../../../Curify/curify_api.yaml', 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)

# Access the API keys and other configuration data
openai_api_key = data.get('openai').get('api_key')
deepseek_api_key = data.get('deepseek').get('api_key')

def call_LLM_api(prompt, model="gpt-4o", max_tokens=5000, retries=3, backoff_factor=2, api_keys=None):
    """
    Send a prompt to either OpenAI (GPT-4o) or DeepSeek API and handle potential errors robustly.

    Parameters:
        prompt (str): The user input or task prompt to send to the model.
        model (str): The model to use ("gpt-4o" for OpenAI or "deepseek-chat" for DeepSeek).
        max_tokens (int): The maximum number of tokens in the response.
        retries (int): Number of retry attempts in case of transient errors.
        backoff_factor (int): Backoff time multiplier for retries.
        api_keys (dict): Dictionary containing API keys with keys "openai" and "deepseek".

    Returns:
        str: The model's response content if successful.
    """
    if model.startswith("gpt-"):
        api_key = openai_api_key
        base_url = "https://api.openai.com/v1"
    elif model.startswith("deepseek"):
        api_key = deepseek_api_key
        base_url = "https://api.deepseek.com"
    else:
        raise ValueError("Unsupported model specified.")
    
    client = OpenAI(api_key=api_key, base_url=base_url)
    
    for attempt in range(1, retries + 1):
        try:
            response = client.chat.completions.create(
                model=model,
                messages=[{"role": "user", "content": prompt}],
                max_tokens=max_tokens,
            )        
            return response.choices[0].message.content.strip()
        
        except (openai.RateLimitError, openai.APIConnectionError) as e:
            logging.warning(f"Transient error: {e}. Attempt {attempt} of {retries}. Retrying...")
        except (openai.BadRequestError, openai.AuthenticationError) as e:
            logging.error(f"Unrecoverable error: {e}. Check your inputs or API key.")
            break
        except Exception as e:
            logging.error(f"Unexpected error: {e}. Attempt {attempt} of {retries}. Retrying...")
        
        # Exponential backoff before retrying
        if attempt < retries:
            time.sleep(backoff_factor * attempt)
    
    raise RuntimeError(f"Failed to fetch response from {model} API after {retries} attempts.")

# List of Tier 1 topics
TIER1_TOPICS = [
    "arts, culture, entertainment and media",
    "crime, law and justice",
    "disaster, accident and emergency incident",
    "economy, business and finance",
    "education",
    "environment",
    "health",
    "human interest",
    "labour",
    "lifestyle and leisure",
    "politics",
    "religion",
    "science and technology",
    "society",
    "sport",
    "conflict, war and peace",
    "weather"
]

TIER1_TOPICS = ['business', 'tech', 'entertainment', 'sport', 'politics']

def classify_tier1_topics(text, model="gpt-4o-mini", api_keys=None):
    """
    Calls an LLM (GPT-4o or DeepSeek) to classify the input text into relevant Tier 1 topics.
    
    Returns:
    {
        "top_topics": ["topic1", "topic2", "topic3"],  # Up to 3 topics
        "primary_topic": "top_topic"  # Most relevant topic
    }
    """
    prompt = f"""
    Given the following article summary, classify it into relevant Tier 1 topics from the list below.
    
    Topics: {TIER1_TOPICS}

    Return a JSON object with the format:
    {{
        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics
        "primary_topic": "top_topic"  # Most relevant topic
    }}

    Ensure the topics are chosen from the provided list.

    Article Summary: "{text}"
    """

    response = call_LLM_api(prompt, model=model, api_keys=api_keys)  # Call LLM API
     # Extract the JSON content using regex to remove extra characters
    match = re.search(r"\{.*\}", response, re.DOTALL)  
    if match:
        json_str = match.group(0)  # Extract the valid JSON
        try:
            data = json.loads(json_str)  # Parse JSON
            if isinstance(data, dict) and "top_topics" in data and "primary_topic" in data:
                return data  # Valid JSON
        except json.JSONDecodeError as e:
            print(f"JSON parsing error: {e}")
    
    # If parsing fails, return a fallback response
    return {"top_topics": [], "primary_topic": None}  

item_df[["top_topics_gpt", "primary_topic_gpt"]] = item_df["summary"].apply(
    lambda x: pd.Series(classify_tier1_topics(x, model="gpt-4o-mini"))
)

item_df[["top_topics_deepseek", "primary_topic_deepseek"]] = item_df["summary"].apply(
    lambda x: pd.Series(classify_tier1_topics(x, model="deepseek-chat"))
)

# Save the labeled DataFrame to CSV
item_df.to_csv("news_summary_labeled.csv", index=False)
print("Labeled data saved to 'news_summary_labeled.csv'")
# Out:
# 2025-03-20 03:26:42,250 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\n    Given the following article summary, classify it into relevant Tier 1 topics from the list below.\n    \n    Topics: [\'business\', \'tech\', \'entertainment\', \'sport\', \'politics\']\n\n    Return a JSON object with the format:\n    {\n        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics\n        "primary_topic": "top_topic"  # Most relevant topic\n    }\n\n    Ensure the topics are chosen from the provided list.\n\n    Article Summary: "All areas saw a rise in annual house price inflation in November except for Northern Ireland and the West Midlands, where the rate was unchanged, the ODPM said.It said annual inflation rose between October and November because prices had fallen by 1.1% in the same period in 2003.In London, the area with the highest average house price at £262,825, annual inflation rose only slightly in November to 7.1% from 7% the previous month.UK house prices dipped slightly in November, the Office of the Deputy Prime Minister (ODPM) has said.But while the monthly figures may hint at a cooling of the market, annual house price inflation is still strong, up 13.8% in the year to November.The ODPM attributed the monthly fall of prices in November to a drop in the value of detached houses and flats.The ODPM data showed the average house price was £192,713 in England; £139,544 in Wales; £116,542 in Scotland, and £111,314 in Northern Ireland.The average house price fell marginally to £180,226, from £180,444 in October."\n    '}], 'model': 'gpt-4o-mini', 'max_tokens': 5000}}
# 2025-03-20 03:26:42,251 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 03:26:42,252 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-03-20 03:26:42,280 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eacdacdc0>
# 2025-03-20 03:26:42,281 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x7f7eae107ac0> server_hostname='api.openai.com' timeout=5.0
# 2025-03-20 03:26:42,288 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eacdafe80>
# 2025-03-20 03:26:42,289 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:42,290 - DEBUG - send_request_headers.complete
# 2025-03-20 03:26:42,290 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:42,292 - DEBUG - send_request_body.complete
# 2025-03-20 03:26:42,292 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:43,719 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 03:26:43 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'744'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1994629'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'161ms'), (b'x-request-id', b'req_1fe0d8f3a96ed7f2ed73159ba3d5d0f5'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=6KlmpIUd8e_hROgtN4EfMzdHSjecZ2LcGRdIp1.QEXk-1742441203-1.0.1.1-yNIFIXF3lEuoNr.Eld7nqEo_3Z_8ZDmjN2YGFwsAM8jexF_tyhvEwyFGWNkrnyNMPM_W.JrTVKI4lr8oKOOAIto4i.lqzBO5l8k1O9Angbc; path=/; expires=Thu, 20-Mar-25 03:56:43 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=KrA3wGDCRbep950PMkU9bHpLIvw3YtuYLXkXwk_XbBM-1742441203717-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92321c0a5d2be5b2-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 03:26:43,720 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 03:26:43,722 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:43,723 - DEBUG - receive_response_body.complete
# 2025-03-20 03:26:43,724 - DEBUG - response_closed.started
# 2025-03-20 03:26:43,725 - DEBUG - response_closed.complete
# 2025-03-20 03:26:43,725 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Thu, 20 Mar 2025 03:26:43 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-gbgqrr8mnjzeosnimrnxpaf7'), ('openai-processing-ms', '744'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '2000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '1994629'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '161ms'), ('x-request-id', 'req_1fe0d8f3a96ed7f2ed73159ba3d5d0f5'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=6KlmpIUd8e_hROgtN4EfMzdHSjecZ2LcGRdIp1.QEXk-1742441203-1.0.1.1-yNIFIXF3lEuoNr.Eld7nqEo_3Z_8ZDmjN2YGFwsAM8jexF_tyhvEwyFGWNkrnyNMPM_W.JrTVKI4lr8oKOOAIto4i.lqzBO5l8k1O9Angbc; path=/; expires=Thu, 20-Mar-25 03:56:43 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=KrA3wGDCRbep950PMkU9bHpLIvw3YtuYLXkXwk_XbBM-1742441203717-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '92321c0a5d2be5b2-IAD'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# 2025-03-20 03:26:43,726 - DEBUG - request_id: req_1fe0d8f3a96ed7f2ed73159ba3d5d0f5
# 2025-03-20 03:26:43,763 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\n    Given the following article summary, classify it into relevant Tier 1 topics from the list below.\n    \n    Topics: [\'business\', \'tech\', \'entertainment\', \'sport\', \'politics\']\n\n    Return a JSON object with the format:\n    {\n        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics\n        "primary_topic": "top_topic"  # Most relevant topic\n    }\n\n    Ensure the topics are chosen from the provided list.\n\n    Article Summary: "A £1.3bn offer from Deutsche Boerse has already been rejected, while Euronext has said it will make an all cash bid.Both Deutsche Boerse and rival Euronext held talks with the London market last week over a possible offer.However, the Sunday Telegraph report added that there are signs that Deutsche Boerse chief executive Werner Seifert is becoming increasingly impatient with the LSE\'s managed bid process.Speculation suggests that Paris-based Euronext has the facilities in place to make a bid of £1.4bn, while its German rival may up its bid to the £1.5bn mark.The newspaper also claimed Mr Seifert was becoming "increasingly frustrated" with the pace of negotiations since Deutsche Boerse\'s £1.3bn offer was rejected in mid-December, in particular the LSE\'s decision to suspend talks over the Christmas period.Unions for Deutsche Boerse staff in Frankfurt have reportedly expressed fears that up to 300 jobs would be moved to London if the takeover is successful."\n    '}], 'model': 'gpt-4o-mini', 'max_tokens': 5000}}
# 2025-03-20 03:26:43,764 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 03:26:43,765 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-03-20 03:26:43,771 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eacd9f850>
# 2025-03-20 03:26:43,771 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x7f7eab3daec0> server_hostname='api.openai.com' timeout=5.0
# 2025-03-20 03:26:43,777 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eacd9c040>
# 2025-03-20 03:26:43,777 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:43,778 - DEBUG - send_request_headers.complete
# 2025-03-20 03:26:43,779 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:43,779 - DEBUG - send_request_body.complete
# 2025-03-20 03:26:43,780 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:44,827 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 03:26:44 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'925'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1994642'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'160ms'), (b'x-request-id', b'req_2966de9eefc6fe2ec82cabad19fc0e79'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=QBPhJGYPOK3o.f8HAJ3d.qQzlfmny7L3WNLicfZHExI-1742441204-1.0.1.1-PALKMjnrfsQ6ScTd53CYQYZwF0oZohOVZWSbV75Himoxs0.1dEJJNuXCi.yYiPk7TnA03MMnNOhw2NlgfGiQVGvEBkzVywnQQj8qvaKT3uA; path=/; expires=Thu, 20-Mar-25 03:56:44 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=PKAMqcMfkiqWmINos6d3ANTtl5WS3vx0OOlgTSPUwgk-1742441204825-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92321c139aff59f7-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 03:26:44,829 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 03:26:44,830 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:44,831 - DEBUG - receive_response_body.complete
# 2025-03-20 03:26:44,832 - DEBUG - response_closed.started
# 2025-03-20 03:26:44,833 - DEBUG - response_closed.complete
# 2025-03-20 03:26:44,833 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Thu, 20 Mar 2025 03:26:44 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-gbgqrr8mnjzeosnimrnxpaf7'), ('openai-processing-ms', '925'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '2000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '1994642'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '160ms'), ('x-request-id', 'req_2966de9eefc6fe2ec82cabad19fc0e79'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=QBPhJGYPOK3o.f8HAJ3d.qQzlfmny7L3WNLicfZHExI-1742441204-1.0.1.1-PALKMjnrfsQ6ScTd53CYQYZwF0oZohOVZWSbV75Himoxs0.1dEJJNuXCi.yYiPk7TnA03MMnNOhw2NlgfGiQVGvEBkzVywnQQj8qvaKT3uA; path=/; expires=Thu, 20-Mar-25 03:56:44 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=PKAMqcMfkiqWmINos6d3ANTtl5WS3vx0OOlgTSPUwgk-1742441204825-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '92321c139aff59f7-IAD'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# 2025-03-20 03:26:44,835 - DEBUG - request_id: req_2966de9eefc6fe2ec82cabad19fc0e79
# 2025-03-20 03:26:44,870 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\n    Given the following article summary, classify it into relevant Tier 1 topics from the list below.\n    \n    Topics: [\'business\', \'tech\', \'entertainment\', \'sport\', \'politics\']\n\n    Return a JSON object with the format:\n    {\n        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics\n        "primary_topic": "top_topic"  # Most relevant topic\n    }\n\n    Ensure the topics are chosen from the provided list.\n\n    Article Summary: "Harinordoquy was a second-half replacement in last Saturday\'s 24-18 defeat to Wales.Rougerie hurt his chest against Wales while Grandclaude was a second-half replacement against both England and Wales.Number eight Imanol Harinordoquy has been dropped from France\'s squad for the Six Nations match with Ireland in Dublin on 12 March."It will be a very exciting game because Ireland have three wins under their belt, have just defeated England and have their eyes set on a Grand Slam.""The Grand Slam is gone but we\'ll go to Ireland to win."Imanol has been dropped from the squad because the least I can say is that he didn\'t make a thundering comeback against Wales," said Laporte."\n    '}], 'model': 'gpt-4o-mini', 'max_tokens': 5000}}
# 2025-03-20 03:26:44,871 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 03:26:44,872 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-03-20 03:26:44,881 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eadfae9b0>
# 2025-03-20 03:26:44,881 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x7f7eab3db1c0> server_hostname='api.openai.com' timeout=5.0
# 2025-03-20 03:26:44,887 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eadfae800>
# 2025-03-20 03:26:44,887 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:44,889 - DEBUG - send_request_headers.complete
# 2025-03-20 03:26:44,889 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:44,890 - DEBUG - send_request_body.complete
# 2025-03-20 03:26:44,891 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:45,546 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 03:26:45 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'543'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1994714'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'158ms'), (b'x-request-id', b'req_ad7b6a9f267f8684157e33369f0ea719'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=_XoV4wFU3v8fbVJF66ejTUDc7.2RKdl6ANF4Qmh3u2I-1742441205-1.0.1.1-a02hr6_0T0cS7PNnKzmQdIPuFVO18Lrv5SOBJPq7YXJ_OSveIg14Xl4gG_qb3QtTsM_0yw_QH8dD19CnosYUasBBephOFTPjhFwwxzkggAM; path=/; expires=Thu, 20-Mar-25 03:56:45 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=tznxU.IfQAbiHC8jeTLz4FJU4HQJEjPLIbg6G8mZz0s-1742441205545-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92321c1a8befd688-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 03:26:45,548 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 03:26:45,549 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:45,550 - DEBUG - receive_response_body.complete
# 2025-03-20 03:26:45,551 - DEBUG - response_closed.started
# 2025-03-20 03:26:45,551 - DEBUG - response_closed.complete
# 2025-03-20 03:26:45,552 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Thu, 20 Mar 2025 03:26:45 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-gbgqrr8mnjzeosnimrnxpaf7'), ('openai-processing-ms', '543'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '2000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '1994714'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '158ms'), ('x-request-id', 'req_ad7b6a9f267f8684157e33369f0ea719'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=_XoV4wFU3v8fbVJF66ejTUDc7.2RKdl6ANF4Qmh3u2I-1742441205-1.0.1.1-a02hr6_0T0cS7PNnKzmQdIPuFVO18Lrv5SOBJPq7YXJ_OSveIg14Xl4gG_qb3QtTsM_0yw_QH8dD19CnosYUasBBephOFTPjhFwwxzkggAM; path=/; expires=Thu, 20-Mar-25 03:56:45 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=tznxU.IfQAbiHC8jeTLz4FJU4HQJEjPLIbg6G8mZz0s-1742441205545-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '92321c1a8befd688-IAD'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# 2025-03-20 03:26:45,553 - DEBUG - request_id: req_ad7b6a9f267f8684157e33369f0ea719
# 2025-03-20 03:26:45,586 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\n    Given the following article summary, classify it into relevant Tier 1 topics from the list below.\n    \n    Topics: [\'business\', \'tech\', \'entertainment\', \'sport\', \'politics\']\n\n    Return a JSON object with the format:\n    {\n        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics\n        "primary_topic": "top_topic"  # Most relevant topic\n    }\n\n    Ensure the topics are chosen from the provided list.\n\n    Article Summary: "Shares in UK banking group Barclays have risen on Monday following a weekend press report that it had held merger talks with US bank Wells Fargo.A tie-up between Barclays and California-based Wells Fargo would create the world\'s fourth biggest bank, valued at $180bn (£96bn).UK banking icon Barclays was founded more than 300 years ago; it has operations in over 60 countries and employs 76,200 staff worldwide.Barclays has declined to comment on the report in the Sunday Express, saying it does not respond to market speculation.In 2003, Barclays reported a 20% rise in pre-tax profits to £3.8bn, and it has recently forecast similar gains in 2004, predicting that full year pre-tax profits would rise 18% to £4.5bn."\n    '}], 'model': 'gpt-4o-mini', 'max_tokens': 5000}}
# 2025-03-20 03:26:45,588 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 03:26:45,588 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-03-20 03:26:45,594 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eaced13f0>
# 2025-03-20 03:26:45,595 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x7f7eae106440> server_hostname='api.openai.com' timeout=5.0
# 2025-03-20 03:26:45,601 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eaced1780>
# 2025-03-20 03:26:45,601 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:45,602 - DEBUG - send_request_headers.complete
# 2025-03-20 03:26:45,602 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:45,603 - DEBUG - send_request_body.complete
# 2025-03-20 03:26:45,604 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:46,467 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 03:26:46 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'741'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1994704'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'158ms'), (b'x-request-id', b'req_6cf7f663594412e3927bccef529e5b72'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=dP2UgF1di1SPPMtEyMD_xOAvwl91c9UhUYY7BaZgKYE-1742441206-1.0.1.1-0YIDIMydbQl3.wc7ZGYTGPnI9aWEs9ZhgAscf7cSF4ieQ8YEzHzikBTjzqvvC8Gu2hhQcmr30FHP3LuX0.mEl4chpF7brz.2c2dKb9aFgOE; path=/; expires=Thu, 20-Mar-25 03:56:46 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=0QUkDkUuGnWdN8cUQ7cjHWtMWkfk3w5OZAQH5szMC44-1742441206466-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92321c1f0cc038fe-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 03:26:46,469 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 03:26:46,469 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:46,474 - DEBUG - receive_response_body.complete
# 2025-03-20 03:26:46,474 - DEBUG - response_closed.started
# 2025-03-20 03:26:46,475 - DEBUG - response_closed.complete
# 2025-03-20 03:26:46,475 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Thu, 20 Mar 2025 03:26:46 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-gbgqrr8mnjzeosnimrnxpaf7'), ('openai-processing-ms', '741'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '2000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '1994704'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '158ms'), ('x-request-id', 'req_6cf7f663594412e3927bccef529e5b72'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=dP2UgF1di1SPPMtEyMD_xOAvwl91c9UhUYY7BaZgKYE-1742441206-1.0.1.1-0YIDIMydbQl3.wc7ZGYTGPnI9aWEs9ZhgAscf7cSF4ieQ8YEzHzikBTjzqvvC8Gu2hhQcmr30FHP3LuX0.mEl4chpF7brz.2c2dKb9aFgOE; path=/; expires=Thu, 20-Mar-25 03:56:46 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=0QUkDkUuGnWdN8cUQ7cjHWtMWkfk3w5OZAQH5szMC44-1742441206466-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '92321c1f0cc038fe-IAD'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# 2025-03-20 03:26:46,476 - DEBUG - request_id: req_6cf7f663594412e3927bccef529e5b72
# 2025-03-20 03:26:46,507 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\n    Given the following article summary, classify it into relevant Tier 1 topics from the list below.\n    \n    Topics: [\'business\', \'tech\', \'entertainment\', \'sport\', \'politics\']\n\n    Return a JSON object with the format:\n    {\n        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics\n        "primary_topic": "top_topic"  # Most relevant topic\n    }\n\n    Ensure the topics are chosen from the provided list.\n\n    Article Summary: "Assistant information commissioner Phil Jones said it was classed as marketing if political parties telephoned people to encourage them to vote for them.Mr Taylor argues there should be new guidelines so all parties can act in the same way if the watchdog believes the rules allow parties to ring TPS numbers about voting intentions and later urge those people to vote for them."If a party is calling someone who is registered on TPS and records their voting intention with a view to using this information in the future, this should be clear to the voter concerned," said Mr Jones."When we ask which party they will vote for, that is not marketing and we have very clear legal advice that it is not," he said.A Conservative spokeswoman said the party stuck to the rules when it rang TPS subscribers.He said the party always asked people if they would be happy to be contacted again and if they said no, they were not rung again."If a party rings a person who is registered on TPS to ask about their voting intention and goes on to encourage that voter to support them, the party may well be in breach of the regulations.The parties say they can stick to the rules by ensuring that their calls are not marketing - for instance by asking about people\'s voting intentions.A Labour Party spokesman told the BBC News website the party avoided those on TPS lists when telephoning people about membership or fundraising.But seven million telephone numbers are on the Telephone Preference Service (TPS) lists, which ban unsolicited sales and marketing calls.She said: "We do apply TPS but in line with the law."\n    '}], 'model': 'gpt-4o-mini', 'max_tokens': 5000}}
# 2025-03-20 03:26:46,508 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 03:26:46,509 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-03-20 03:26:46,535 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eace678e0>
# 2025-03-20 03:26:46,536 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x7f7eae1076c0> server_hostname='api.openai.com' timeout=5.0
# 2025-03-20 03:26:46,542 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eace64730>
# 2025-03-20 03:26:46,542 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:46,543 - DEBUG - send_request_headers.complete
# 2025-03-20 03:26:46,544 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:46,545 - DEBUG - send_request_body.complete
# 2025-03-20 03:26:46,545 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:47,295 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 03:26:47 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'627'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1994484'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'165ms'), (b'x-request-id', b'req_e91df51314964db1070166cfcf9badfe'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=Ukr.cj5iWOesXCNa2LTiXNbclMGpepoLSIXZu3_uBQM-1742441207-1.0.1.1-tYGtPhCNtTx06UY2j8r22jMjcEHPLC6txA.pn85o3IwHZwrKpyyCTcGJkbNQ3rTJWQhbCx0403q097Z4V3_gUbrYEMwDnNXmPurOFMGRbo0; path=/; expires=Thu, 20-Mar-25 03:56:47 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=s__.RsGHkq.xaXfyCD93lKBXudrjxpY31rcRpJfuNsI-1742441207294-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92321c24ea135967-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 03:26:47,297 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 03:26:47,297 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:47,299 - DEBUG - receive_response_body.complete
# 2025-03-20 03:26:47,299 - DEBUG - response_closed.started
# 2025-03-20 03:26:47,300 - DEBUG - response_closed.complete
# 2025-03-20 03:26:47,300 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Thu, 20 Mar 2025 03:26:47 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-gbgqrr8mnjzeosnimrnxpaf7'), ('openai-processing-ms', '627'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '2000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '1994484'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '165ms'), ('x-request-id', 'req_e91df51314964db1070166cfcf9badfe'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=Ukr.cj5iWOesXCNa2LTiXNbclMGpepoLSIXZu3_uBQM-1742441207-1.0.1.1-tYGtPhCNtTx06UY2j8r22jMjcEHPLC6txA.pn85o3IwHZwrKpyyCTcGJkbNQ3rTJWQhbCx0403q097Z4V3_gUbrYEMwDnNXmPurOFMGRbo0; path=/; expires=Thu, 20-Mar-25 03:56:47 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=s__.RsGHkq.xaXfyCD93lKBXudrjxpY31rcRpJfuNsI-1742441207294-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '92321c24ea135967-IAD'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# 2025-03-20 03:26:47,301 - DEBUG - request_id: req_e91df51314964db1070166cfcf9badfe
# 2025-03-20 03:26:47,336 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\n    Given the following article summary, classify it into relevant Tier 1 topics from the list below.\n    \n    Topics: [\'business\', \'tech\', \'entertainment\', \'sport\', \'politics\']\n\n    Return a JSON object with the format:\n    {\n        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics\n        "primary_topic": "top_topic"  # Most relevant topic\n    }\n\n    Ensure the topics are chosen from the provided list.\n\n    Article Summary: "Gray, who has been caretaker manager, was assistant boss when Hoddle was manager at Southampton.Glenn Hoddle has been unveiled as the new Wolves manager.Hoddle, who will work alongside Stuart Gray, has been out of the game since he was sacked by Spurs in 2003.The ex-England coach has been given a six-month contract to succeed Dave Jones, who was sacked after the club\'s poor start to the season.The 47-year-old later returned to management with Southampton, where he again succeeded Jones - as he has now done at Wolves."I\'m delighted to be here," said Hoddle."Stuart Gray has done a fantastic job as caretaker manager.Wolves chief executive Jez Moxey defended the decision to give Hoddle a short-term contract.Wolves chairman Rick Hayward said: "We\'re delighted Glenn is here.Hayward revealed that Hoddle was one of the first to be approached after Jones\' departure."\n    '}], 'model': 'gpt-4o-mini', 'max_tokens': 5000}}
# 2025-03-20 03:26:47,337 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 03:26:47,338 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-03-20 03:26:47,364 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eaddbd4e0>
# 2025-03-20 03:26:47,364 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x7f7eae106040> server_hostname='api.openai.com' timeout=5.0
# 2025-03-20 03:26:47,371 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eb27d0370>
# 2025-03-20 03:26:47,372 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:47,373 - DEBUG - send_request_headers.complete
# 2025-03-20 03:26:47,373 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:47,374 - DEBUG - send_request_body.complete
# 2025-03-20 03:26:47,375 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:48,141 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 03:26:48 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'657'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1994668'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'159ms'), (b'x-request-id', b'req_fcc0437f4aa51f99a0e27953efe32088'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=eKzF36PHaeYGctzP.fM.bxn.Atob1uQ7VW7oDmewhME-1742441208-1.0.1.1-0M9PyxPu.KEwT4oV3K1hO3UIbRHQnn60Df.Eu7rsYll1Pj_VsHdNuuQwFYhQ47Q2CnimWwTe9o44UT8DppGORfPZjE8NcD.ZPe6WflsDjJ8; path=/; expires=Thu, 20-Mar-25 03:56:48 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=_no06ET0Sw7iMi47bWeRcabC9rPPU6eK_gHsYPA06uU-1742441208139-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92321c2a1c701759-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 03:26:48,143 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 03:26:48,144 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:48,145 - DEBUG - receive_response_body.complete
# 2025-03-20 03:26:48,146 - DEBUG - response_closed.started
# 2025-03-20 03:26:48,146 - DEBUG - response_closed.complete
# 2025-03-20 03:26:48,147 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Thu, 20 Mar 2025 03:26:48 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-gbgqrr8mnjzeosnimrnxpaf7'), ('openai-processing-ms', '657'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '2000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '1994668'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '159ms'), ('x-request-id', 'req_fcc0437f4aa51f99a0e27953efe32088'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=eKzF36PHaeYGctzP.fM.bxn.Atob1uQ7VW7oDmewhME-1742441208-1.0.1.1-0M9PyxPu.KEwT4oV3K1hO3UIbRHQnn60Df.Eu7rsYll1Pj_VsHdNuuQwFYhQ47Q2CnimWwTe9o44UT8DppGORfPZjE8NcD.ZPe6WflsDjJ8; path=/; expires=Thu, 20-Mar-25 03:56:48 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=_no06ET0Sw7iMi47bWeRcabC9rPPU6eK_gHsYPA06uU-1742441208139-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '92321c2a1c701759-IAD'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# 2025-03-20 03:26:48,148 - DEBUG - request_id: req_fcc0437f4aa51f99a0e27953efe32088
# 2025-03-20 03:26:48,181 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\n    Given the following article summary, classify it into relevant Tier 1 topics from the list below.\n    \n    Topics: [\'business\', \'tech\', \'entertainment\', \'sport\', \'politics\']\n\n    Return a JSON object with the format:\n    {\n        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics\n        "primary_topic": "top_topic"  # Most relevant topic\n    }\n\n    Ensure the topics are chosen from the provided list.\n\n    Article Summary: "Williams was also far from content.Davenport defeated China\'s Jie Zheng 6-2 7-5, while French Open champion Myskina sailed through after her opponent Marion Bartoli retired hurt."I don\'t know what I was doing there," she said."I feel I have an advantage (over Serena) because I have already played two matches on these courts," she said.Daniela Hantuchova moved into the quarter-finals of the Dubai Open, after beating Elene Likhotseva of Russia 7-5 6-4, and now faces Serena Williams."It was really windy and I hadn\'t played in the wind.But Hantuchova is in upbeat mood ahead of her clash with the younger Williams sister, who was handed a first-round bye."\n    '}], 'model': 'gpt-4o-mini', 'max_tokens': 5000}}
# 2025-03-20 03:26:48,182 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 03:26:48,183 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-03-20 03:26:48,199 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eb27d0940>
# 2025-03-20 03:26:48,200 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x7f7eae105540> server_hostname='api.openai.com' timeout=5.0
# 2025-03-20 03:26:48,209 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eb27d2ec0>
# 2025-03-20 03:26:48,209 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:48,210 - DEBUG - send_request_headers.complete
# 2025-03-20 03:26:48,211 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:48,212 - DEBUG - send_request_body.complete
# 2025-03-20 03:26:48,213 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:49,033 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 03:26:49 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'698'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1994721'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'158ms'), (b'x-request-id', b'req_fe17f154b12b410c5e01bf46bb17fdc1'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=.ppzea6wEw8..MNZsdCtjm.zSfY_JsD8tKl9r1v4l6Y-1742441209-1.0.1.1-8UCGlfVj7F_vZCpXgv2duuLi7S10okFZ_BKozunKm7krKlksXWKY.Hixh1TUXD0iXigTdl047srjwqQIb8L.d5lvUOkHFzshXUHFPk2XwMw; path=/; expires=Thu, 20-Mar-25 03:56:49 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=jr4N9Z4EnFVK2UjZ3zcte8DsH7Il1wcFHSEnjXxSRA4-1742441209031-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92321c2f58b1c5ae-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 03:26:49,034 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 03:26:49,035 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:49,037 - DEBUG - receive_response_body.complete
# 2025-03-20 03:26:49,037 - DEBUG - response_closed.started
# 2025-03-20 03:26:49,038 - DEBUG - response_closed.complete
# 2025-03-20 03:26:49,038 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers([('date', 'Thu, 20 Mar 2025 03:26:49 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-organization', 'user-gbgqrr8mnjzeosnimrnxpaf7'), ('openai-processing-ms', '698'), ('openai-version', '2020-10-01'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '2000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '1994721'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '158ms'), ('x-request-id', 'req_fe17f154b12b410c5e01bf46bb17fdc1'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=.ppzea6wEw8..MNZsdCtjm.zSfY_JsD8tKl9r1v4l6Y-1742441209-1.0.1.1-8UCGlfVj7F_vZCpXgv2duuLi7S10okFZ_BKozunKm7krKlksXWKY.Hixh1TUXD0iXigTdl047srjwqQIb8L.d5lvUOkHFzshXUHFPk2XwMw; path=/; expires=Thu, 20-Mar-25 03:56:49 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=jr4N9Z4EnFVK2UjZ3zcte8DsH7Il1wcFHSEnjXxSRA4-1742441209031-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '92321c2f58b1c5ae-IAD'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# 2025-03-20 03:26:49,039 - DEBUG - request_id: req_fe17f154b12b410c5e01bf46bb17fdc1
# 2025-03-20 03:26:49,073 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\n    Given the following article summary, classify it into relevant Tier 1 topics from the list below.\n    \n    Topics: [\'business\', \'tech\', \'entertainment\', \'sport\', \'politics\']\n\n    Return a JSON object with the format:\n    {\n        "top_topics": ["topic1", "topic2", "topic3"],  # At most 3 topics\n        "primary_topic": "top_topic"  # Most relevant topic\n    }\n\n    Ensure the topics are chosen from the provided list.\n\n    Article Summary: ""We do not underestimate the scale of the challenge before us because the courts have never before overturned a government White Paper," said Stop Stansted Expansion chairman Peter Sanders said.Stop Stansted Expansion said the White Paper, published in December 2003, was "fundamentally flawed" and did not follow the proper consultation process.UK airport operator BAA has reiterated its support for the government\'s aviation expansion plans to airports throughout the country.The judicial review will centre on government plans for expansion at Heathrow, Stansted and Luton airports.HACAN chairman John Stewart said: "Almost exactly a year ago the government published its 30-year aviation White Paper with much fanfare.At Heathrow, Gatwick, Edinburgh and Glasgow airports, BAA launched a series of consultations on blight to properties from the proposed expansion in September 2004, which will close next week.BAA, which operates all three, said it was consulting with local communities."\n    '}], 'model': 'gpt-4o-mini', 'max_tokens': 5000}}
# 2025-03-20 03:26:49,074 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 03:26:49,075 - DEBUG - connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2025-03-20 03:26:49,081 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eadaa3ac0>
# 2025-03-20 03:26:49,082 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x7f7eae1060c0> server_hostname='api.openai.com' timeout=5.0
# 2025-03-20 03:26:49,087 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f7eadf491b0>
# 2025-03-20 03:26:49,087 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:49,088 - DEBUG - send_request_headers.complete
# 2025-03-20 03:26:49,089 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:49,090 - DEBUG - send_request_body.complete
# 2025-03-20 03:26:49,090 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-03-20 03:26:50,483 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 03:26:50 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'1253'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1994637'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'160ms'), (b'x-request-id', b'req_ceed7e3b6a7182b79cd7d61d120c4746'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=Nglt7I3G9TvMCJoY6XWrq_Z4w8WCeBDCmOsXEDqPKfU-1742441210-1.0.1.1-UvA8hvUHV1HfJNfkucT.grukvqIaMmUDrj.aCffE8gagcFrgpGgFVOFbCHQr0q5Gl7lX4f_N8WMOvtGmXbhLtHFgDWLQc229H8A5lie_IiU; path=/; expires=Thu, 20-Mar-25 03:56:50 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=oos8iS4sqDgDGYjdnJzmlbRrbpt8k56HjO9bzstGFR8-1742441210480-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92321c34ca8805c8-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 03:26:50,484 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 03:26:50,485 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 03:26:50,528 - DEBUG - receive_response_body.complete
# 2025-03-20 03:26:50,529 - DEBUG - response_closed.started
# 2025-03-20 03:26:50,529 - DEBUG - response_closed.complete
# ...
# 2025-03-20 03:27:06,117 - DEBUG - receive_response_headers.failed exception=KeyboardInterrupt()
# 2025-03-20 03:27:06,118 - DEBUG - response_closed.started
# 2025-03-20 03:27:06,119 - DEBUG - response_closed.complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 144
#     141     # If parsing fails, return a fallback response
#     142     return {"top_topics": [], "primary_topic": None}
# --> 144 item_df[["top_topics_gpt", "primary_topic_gpt"]] = item_df["summary"].apply(
#     145     lambda x: pd.Series(classify_tier1_topics(x, model="gpt-4o-mini"))
#     146 )
#     148 item_df[["top_topics_deepseek", "primary_topic_deepseek"]] = item_df["summary"].apply(
#     149     lambda x: pd.Series(classify_tier1_topics(x, model="deepseek-chat"))
#     150 )
#     152 # Save the labeled DataFrame to CSV
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[56], line 145, in <lambda>(x)
#     141     # If parsing fails, return a fallback response
#     142     return {"top_topics": [], "primary_topic": None}
#     144 item_df[["top_topics_gpt", "primary_topic_gpt"]] = item_df["summary"].apply(
# --> 145     lambda x: pd.Series(classify_tier1_topics(x, model="gpt-4o-mini"))
#     146 )
#     148 item_df[["top_topics_deepseek", "primary_topic_deepseek"]] = item_df["summary"].apply(
#     149     lambda x: pd.Series(classify_tier1_topics(x, model="deepseek-chat"))
#     150 )
#     152 # Save the labeled DataFrame to CSV
#
# Cell In[56], line 129, in classify_tier1_topics(text, model, api_keys)
#     104 """
#     105 Calls an LLM (GPT-4o or DeepSeek) to classify the input text into relevant Tier 1 topics.
#     106
#    (...)
#     111 }
#     112 """
#     113 prompt = f"""
#     114 Given the following article summary, classify it into relevant Tier 1 topics from the list below.
#     115
#    (...)
#     126 Article Summary: "{text}"
#     127 """
# --> 129 response = call_LLM_api(prompt, model=model, api_keys=api_keys)  # Call LLM API
#     130  # Extract the JSON content using regex to remove extra characters
#     131 match = re.search(r"\{.*\}", response, re.DOTALL)
#
# Cell In[56], line 59, in call_LLM_api(prompt, model, max_tokens, retries, backoff_factor, api_keys)
#      57 for attempt in range(1, retries + 1):
#      58     try:
# ---> 59         response = client.chat.completions.create(
#      60             model=model,
#      61             messages=[{"role": "user", "content": prompt}],
#      62             max_tokens=max_tokens,
#      63         )
#      64         return response.choices[0].message.content.strip()
#      66     except (openai.RateLimitError, openai.APIConnectionError) as e:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)
#     911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/openai/_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130         return self._sslobj.read(len, buffer)
#    1131     else:
# -> 1132         return self._sslobj.read(len)
#    1133 except SSLError as x:
#    1134     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Step 4: Evaluate Multi-LLM Labeling Quality for Topic Classification
# - Generate cross-tabulation of primary topics labeled with GPT-4o and deepseek-V3.
# - Display cases where the models disagree with human assessment.

# %%
import pandas as pd

# Create a file to log results
output_file = "classification_evaluation.txt"
with open(output_file, "w") as f:

    # 1. Agreement between GPT and DeepSeek
    item_df["gpt_deepseek_agreement"] = item_df["primary_topic_gpt"] == item_df["primary_topic_deepseek"]
    agreement_rate = item_df["gpt_deepseek_agreement"].mean()

    f.write("=== GPT vs DeepSeek Agreement ===\n")
    f.write(f"Agreement Rate: {agreement_rate:.2%}\n\n")

    # 2. Accuracy of GPT and DeepSeek compared to true category
    gpt_accuracy = (item_df["primary_topic_gpt"] == item_df["category"]).mean()
    deepseek_accuracy = (item_df["primary_topic_deepseek"] == item_df["category"]).mean()

    f.write("=== Classification Accuracy ===\n")
    f.write(f"GPT Accuracy: {gpt_accuracy:.2%}\n")
    f.write(f"DeepSeek Accuracy: {deepseek_accuracy:.2%}\n\n")
    
    # 3. Confusion Matrix (Optional Detailed View)
    f.write("=== GPT Confusion Matrix ===\n")
    gpt_confmat = pd.crosstab(item_df["category"], item_df["primary_topic_gpt"])
    f.write(gpt_confmat.to_string())  # cleaner formatting
    f.write("\n\n")

    f.write("=== DeepSeek Confusion Matrix ===\n")
    deepseek_confmat = pd.crosstab(item_df["category"], item_df["primary_topic_deepseek"])
    f.write(deepseek_confmat.to_string())
    f.write("\n\n")

    # 4. Examples where GPT and DeepSeek disagree
    disagreement_df = item_df[item_df["primary_topic_gpt"] != item_df["primary_topic_deepseek"]]
    f.write("=== Example Disagreements Between GPT and DeepSeek ===\n")
    f.write(disagreement_df[["summary", "category", "primary_topic_gpt", "primary_topic_deepseek"]].head(20).to_string(index=False))
    f.write("\n\n")

    # 5. Save full disagreement cases to CSV (optional)
    disagreement_df.to_csv("disagreement_cases.csv", index=False)

print(f"✅ Evaluation completed. Results saved to: {output_file}")

# %% [markdown]
# #### Step 4: Item Similarity Labeling Using Similarity Matrix and LLM Prompts
# - Generate embeddings for all articles to compute similarity.
# - Use cosine similarity to compute pairwise similarities and filter pairs above a threshold.
# - Use a prompt to ask the LLM to verify if two articles are similar.

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np
import json
import os

from openai import OpenAI

def clean_json_string(text):
    if text.startswith("```json"):
        text = text.replace("```json", "").replace("```", "").strip()
    return text

import torch
import numpy as np

def generate_embeddings(texts, model, tokenizer, batch_size=32, embedding_dim=384, device='cpu'):
    """
    Generate dense embeddings for a list of texts using a pre-trained transformer model.

    Args:
        texts (list of str): Input text corpus.
        model: HuggingFace model for embeddings (e.g., sentence-transformers or AutoModel).
        tokenizer: Tokenizer matching the model.
        batch_size (int): Batch size for batched inference.
        embedding_dim (int): Dimension of the embedding vectors.
        device (str): 'cpu' or 'cuda'.

    Returns:
        np.ndarray: Embedding matrix of shape (len(texts), embedding_dim)
    """
    model.to(device)
    model.eval()
    all_embeddings = []

    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            encoded_input = tokenizer(batch_texts, padding=True, truncation=True, return_tensors='pt').to(device)

            model_output = model(**encoded_input)
            if hasattr(model_output, 'last_hidden_state'):
                # Mean pooling over sequence
                embeddings = model_output.last_hidden_state.mean(dim=1)
            elif hasattr(model_output, 'pooler_output'):
                embeddings = model_output.pooler_output
            else:
                raise ValueError("Unsupported model output structure.")

            all_embeddings.append(embeddings.cpu())

    all_embeddings = torch.cat(all_embeddings, dim=0)
    return all_embeddings.numpy()

def find_approximate_neighbors(embeddings, k=20, threshold=0.7):
    """
    Use approximate nearest neighbor (ANN) search to find top-k similar pairs with similarity scores.
    
    Returns:
        List of tuples: [(i, j, similarity), ...]
    """
    nbrs = NearestNeighbors(n_neighbors=k, metric='cosine').fit(embeddings)
    distances, indices = nbrs.kneighbors(embeddings)
    similar_pairs = []

    for i, (dists, idxs) in enumerate(zip(distances, indices)):
        for j, dist in zip(idxs, dists):
            if i < j:  # avoid duplicates
                similarity = 1 - dist
                if similarity >= threshold:
                    similar_pairs.append((i, j, similarity))

    return similar_pairs

def call_openai_api_batch(similar_pairs, texts, batch_size=10, model="gpt-4o-mini"):
    """
    Calls OpenAI API in batches with similarity-aware pairs.
    
    Args:
        similar_pairs (list): List of (i, j, similarity).
        texts (list): List of article texts.
        batch_size (int): API batch size.
        model (str): Model name.
        openai_api_key (str): Your OpenAI API key.
    
    Returns:
        List of dicts: [{"pair": (text1, text2), "similarity": float, "label": 0/1, "reasoning": str}]
    """
    all_results = []
    client = OpenAI(api_key=openai_api_key)

    for i in range(0, len(similar_pairs), batch_size):
        batch = similar_pairs[i:i + batch_size]

        for idx1, idx2, sim in batch:
            text1 = texts[idx1]
            text2 = texts[idx2]

            prompt = f"""
You are a helpful assistant for text similarity analysis.
Are these two articles discussing the same topic?

Article 1: "{text1}"
Article 2: "{text2}"

Provide your reasoning and output in strict JSON format:
{{
  "reasoning": "Explain your decision briefly",
  "answer": "Yes" or "No"
}}"""

            try:
                response = client.chat.completions.create(
                    model=model,
                    messages=[{"role": "user", "content": prompt}],
                    max_tokens=300,
                    temperature=0.2
                )

                content = response.choices[0].message.content.strip()
                content = clean_json_string(content)

                try:
                    parsed = json.loads(content)
                    answer = parsed.get("answer", "").strip().lower()
                    label = 1 if answer == "yes" else 0
                    reasoning = parsed.get("reasoning", "")

                except Exception as parse_err:
                    print(f"⚠️ JSON parsing error for pair ({idx1}, {idx2}): {parse_err}")
                    label = 0
                    reasoning = "Failed to parse JSON response"

            except Exception as api_err:
                print(f"❌ API error for pair ({idx1}, {idx2}): {api_err}")
                label = 0
                reasoning = "API call failed"

            all_results.append({
                "pair": (text1, text2),
                "similarity": sim,
                "label": label,
                "reasoning": reasoning
            })

            print(f"\n✅ Pair (sim={sim:.3f}): \n🔸 Article 1: {text1[:100]}...\n🔸 Article 2: {text2[:100]}...\n➡ Label: {label}, Reason: {reasoning[:150]}")

    return all_results

def process_articles(texts, item_ids, k=20, threshold=0.7, batch_size=10):
    """
    Process articles and classify all ANN pairs using OpenAI API validation.
    
    Returns:
        similarity_matrix: Dict {(text_1, text_2): label}
        reasoning_dict: Dict {(text_1, text_2): reasoning_text}
    """
    if len(texts) != len(item_ids):
        raise ValueError("texts and item_ids must have the same length.")

    total_start_time = time.time()

    # Step 1: Embedding
    start_time = time.time()
    embeddings = generate_embeddings(texts, model, tokenizer)

    embedding_time = time.time() - start_time
    print(f"✅ Embedding generation time: {embedding_time:.2f}s")

    # Step 2: ANN search
    start_time = time.time()
    similar_pairs = find_approximate_neighbors(embeddings, k=k, threshold=threshold)
    ann_time = time.time() - start_time
    print(f"✅ ANN search time: {ann_time:.2f}s")

    # Step 3: OpenAI validation
    start_time = time.time()
    pair_results = call_openai_api_batch(similar_pairs, texts, batch_size=batch_size)
    api_time = time.time() - start_time
    print(f"✅ OpenAI API time: {api_time:.2f}s")

    total_time = time.time() - total_start_time

    # Summary
    print("\n=== ⏳ Timing Summary ===")
    print(f"🔹 Embedding: {embedding_time:.2f}s")
    print(f"🔹 ANN: {ann_time:.2f}s")
    print(f"🔹 OpenAI Validation: {api_time:.2f}s")
    print(f"🔹 Total: {total_time:.2f}s")
    print("========================")

    return len(similar_pairs), pair_results, total_time, api_time

# %% [markdown]
# #### Step 6: Evaluate Batch Inference Latency

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assume final_1 is your list of results
# Example format:
# final_1 = [{"pair": (...), "similarity": 0.85, "label": 1, "reasoning": "..."}, ...]
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_similarity_vs_label(results, output_file="similarity_vs_label.png"):
    """
    Plot cosine similarity vs. binary label and save to local file.
    
    Args:
        results (list of dict): List of {"pair": (text1, text2), "similarity": float, "label": int, ...}
        output_file (str): File path to save the plot.
    """
    # Convert to DataFrame
    df = pd.DataFrame(results)
    
    # Create the plot
    plt.figure(figsize=(7, 5))
    sns.stripplot(x='label', y='similarity', data=df, jitter=True, palette='Set1', alpha=0.7)

    # Formatting
    plt.title("Similarity vs Label")
    plt.xlabel("Label (0 = Not Similar, 1 = Similar)")
    plt.ylabel("Cosine Similarity Score")
    plt.grid(True, linestyle="--", alpha=0.3)
    plt.tight_layout()
    
    # Save to file
    plt.savefig(output_file, dpi=300)
    plt.close()
    print(f"Plot saved to: {output_file}")

from sklearn.metrics import roc_auc_score

def compute_auc_score(results):
    similarities = [r["similarity"] for r in results]
    labels = [r["label"] for r in results]
    auc = roc_auc_score(labels, similarities)
    return auc

# %%
# Example usage
num_sample = 500
num_k = 10
item_head = item_df.sample(frac=1, random_state=42).head(num_sample).reset_index(drop=True)
texts = item_head['summary'].tolist()
item_ids = item_head['item_id'].tolist()  # Assuming item_df has 'item_id' column

# Run article processing with timing by setting different batch size.
label_vol_1, final_1, total_time_1, api_time_1 = process_articles(texts, item_ids, k=num_k, batch_size=1)


auc_score = compute_auc_score(final_1)
print(f"AUC-ROC Score: {auc_score:.4f}")

# Serialize both results
results_combined = {
"Results 1": final_1,
    "Batch size 1": api_time_1,
    "Label vol 1": label_vol_1,
    "AUC": auc_score
}

plot_similarity_vs_label(final_1)

# Save to JSON file
with open("batch_latency.json", "w") as f:
    json.dump(results_combined, f, indent=2, default=str)
# Out:
# ✅ Embedding generation time: 29.29s
# ✅ ANN search time: 0.03s
#
# ✅ Pair (sim=0.836):
# 🔸 Article 1: O'Gara missed a penalty which would have put Ireland nine points clear, and the home crowd breathed ...
# 🔸 Article 2: Ireland got themselves on the scoreboard with an O'Gara penalty and by the 24th minute the visitors ...
# ➡ Label: 1, Reason: Both articles discuss matches involving the Irish rugby team during the Six Nations tournament. Article 1 focuses on Ireland's victory over England, h
#
# ✅ Pair (sim=0.811):
# 🔸 Article 1: The biggest single project to be halted was the Xiluodi Dam project, designed to produce 12,600 MW o...
# 🔸 Article 2: The China Three Gorges Project Corp is refusing to obey a government order to stop construction of o...
# ➡ Label: 1, Reason: Both articles discuss the construction of dams in China, particularly focusing on the Three Gorges Dam and related projects. Article 1 highlights the
#
# ✅ Pair (sim=0.870):
# 🔸 Article 1: Deutsche Boerse bosses have held "constructive, professional and friendly" talks with the London Sto...
# 🔸 Article 2: Bosses of Deutsche Boerse and the London Stock Exchange are to meet amid talk that a takeover bid fo...
# ➡ Label: 1, Reason: Both articles discuss the ongoing negotiations and potential takeover bids involving Deutsche Boerse and the London Stock Exchange (LSE). They mention
#
# ✅ Pair (sim=0.841):
# 🔸 Article 1: Deutsche Boerse bosses have held "constructive, professional and friendly" talks with the London Sto...
# 🔸 Article 2: Last week, the LSE rejected a takeover proposal from German rival Deutsche Boerse - the 530 pence-a-...
# ➡ Label: 1, Reason: Both articles discuss the recent interactions and negotiations between Deutsche Boerse and the London Stock Exchange (LSE) regarding takeover bids. Th
#
# ✅ Pair (sim=0.809):
# 🔸 Article 1: Deutsche Boerse bosses have held "constructive, professional and friendly" talks with the London Sto...
# 🔸 Article 2: It said Deutsche Boerse had to show why its planned £1.35bn ($2.5bn) offer for the LSE was good for ...
# ➡ Label: 1, Reason: Both articles discuss Deutsche Boerse's attempts to acquire the London Stock Exchange (LSE) and the associated challenges and considerations regarding
#
# ✅ Pair (sim=0.797):
# 🔸 Article 1: Deutsche Boerse bosses have held "constructive, professional and friendly" talks with the London Sto...
# 🔸 Article 2: Commentators say that a deal with Euronext, which owns the Liffe derivatives exchange in London and ...
# ➡ Label: 1, Reason: Both articles discuss potential takeover bids involving the London Stock Exchange (LSE) by Deutsche Boerse and Euronext. They mention the ongoing talk
#
# ✅ Pair (sim=0.790):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: Blackburn have said all along that they want £6m for the midfielder and Williams has rejected propos...
# ➡ Label: 0, Reason: Article 1 discusses the potential acquisition of Manchester United by Malcolm Glazer, focusing on his stake in the club and the details of his bid. Ar
#
# ✅ Pair (sim=0.770):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: Bath and England centre Mike Tindall believes he can make this summer's Lions tour, despite missing ...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on the ownership and financial dealings related to Manchester United, specifical
#
# ✅ Pair (sim=0.769):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: Commentators say that a deal with Euronext, which owns the Liffe derivatives exchange in London and ...
# ➡ Label: 0, Reason: Article 1 discusses a potential takeover bid for Manchester United by Malcolm Glazer, focusing on his ownership stake and previous bids. Article 2, on
#
# ✅ Pair (sim=0.766):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: Leicester and Saracens are believed to head the list of rugby union clubs interested in signing Farr...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on the ownership and bidding situation regarding Manchester United, specifically
#
# ✅ Pair (sim=0.757):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: Shares in engineering group Jarvis have soared more than 16% on news that it is offloading its stake...
# ➡ Label: 0, Reason: Article 1 discusses the ownership and financial proposals related to Manchester United, specifically focusing on Malcolm Glazer's attempts to buy the
#
# ✅ Pair (sim=0.756):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: "First time buyers are being squeezed out of the housing market not only by higher house prices but ...
# ➡ Label: 0, Reason: Article 1 discusses the ownership and bidding situation surrounding Manchester United, specifically focusing on Malcolm Glazer's attempts to buy the c
#
# ✅ Pair (sim=0.755):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: Arsenal boss Arsene Wenger says he has no plans to sign a new goalkeeper during the January transfer...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on Malcolm Glazer's attempts to buy Manchester United and the reactions surround
#
# ✅ Pair (sim=0.753):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: On Wednesday, Prime Minister Yulia Tymoshenko said as many as 3,000 firms could be included on the l...
# ➡ Label: 0, Reason: Article 1 discusses the ownership and bidding situation surrounding Manchester United, specifically focusing on Malcolm Glazer's attempts to acquire a
#
# ✅ Pair (sim=0.749):
# 🔸 Article 1: Glazer, currently owns a 28.1% stake in the club, and United's statement to the stock exchange said:...
# 🔸 Article 2: Reid rejected a move to Southampton after Forest accepted a cash-plus-players offer while Spurs had ...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on Malcolm Glazer's attempts to buy Manchester United and the related financial implicati
#
# ✅ Pair (sim=0.819):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: Industrial output rose 2.1% - adjusted for the time of year - in January from a month earlier.Weaker...
# ➡ Label: 1, Reason: Both articles discuss Japan's economy, focusing on growth rates and economic performance. Article 1 highlights a very slow growth rate and the risk of
#
# ✅ Pair (sim=0.796):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: Growth was at an annual rate of 4% in the third quarter of 2004 and for the year it came in at 4.4%,...
# ➡ Label: 0, Reason: Article 1 discusses Japan's economic performance, specifically focusing on a very low growth rate and the possibility of a recession. In contrast, Art
#
# ✅ Pair (sim=0.761):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: Mortgage lending rose by £7.1bn in December, up from a £6.4bn rise in November.Changes to mortgage r...
# ➡ Label: 0, Reason: Article 1 discusses economic growth and the possibility of a recession in Japan, focusing on GDP figures and economic recovery. Article 2, on the othe
#
# ✅ Pair (sim=0.758):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: The job gains mean that President Bush can celebrate - albeit by a very fine margin - a net growth i...
# ➡ Label: 0, Reason: The two articles discuss different aspects of economic performance. Article 1 focuses on Japan's economic growth and the possibility of a recession, w
#
# ✅ Pair (sim=0.744):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: Plans to shed 71,000 civil service jobs will prove to be a "false economy" that could hamper public ...
# ➡ Label: 0, Reason: Article 1 discusses economic growth and the possibility of a recession in Japan, focusing on economic indicators and performance. Article 2, on the ot
#
# ✅ Pair (sim=0.738):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: Despite a short-lived increase in Palestinian jobs in 2003, the economy is performing well below its...
# ➡ Label: 0, Reason: The two articles discuss different economic situations. Article 1 focuses on Japan's economic growth and the possibility of a technical recession, whi
#
# ✅ Pair (sim=0.730):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: The Commerce Department said the trade deficit for all of last year was 24.4% above the previous rec...
# ➡ Label: 0, Reason: Article 1 discusses Japan's economic growth and the possibility of a recession, focusing on GDP figures and economic recovery. Article 2, on the other
#
# ✅ Pair (sim=0.728):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: "[The unemployment figures] show the main problem of the French economy: we have growth but without ...
# ➡ Label: 0, Reason: Article 1 discusses Japan's economic growth and the risk of a technical recession, focusing on negative growth figures. Article 2, on the other hand,
#
# ✅ Pair (sim=0.727):
# 🔸 Article 1: On an annual basis, the data suggests annual growth of just 0.2%, suggesting a much more hesitant re...
# 🔸 Article 2: The value of trade in April-July rose to $186.3m (£97m) from $64.4m in the same period in 2003, the ...
# ➡ Label: 0, Reason: Article 1 discusses economic growth and the possibility of a recession in Japan, focusing on negative growth rates and economic recovery. Article 2, o
#
# ✅ Pair (sim=0.815):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: The premier was responding to a challenge from Tory leader Michael Howard who said Labour would rais...
# ➡ Label: 1, Reason: Both articles discuss the political debate between the Conservative Party and Labour regarding tax cuts and public spending. They highlight the contra
#
# ✅ Pair (sim=0.802):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: Mr Howard said the plan would also even out the "great unfairness" of there being proportionately mo...
# ➡ Label: 0, Reason: The two articles discuss different topics related to political issues in the UK. Article 1 focuses on the contrasting economic policies of the Conserv
#
# ✅ Pair (sim=0.794):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: Tory backbencher Edward Leigh said the proposals were a step in the right direction but he told the ...
# ➡ Label: 1, Reason: Both articles discuss the Conservative Party's tax plans and their implications for public services, particularly in the context of an upcoming electi
#
# ✅ Pair (sim=0.773):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: Plans to shed 71,000 civil service jobs will prove to be a "false economy" that could hamper public ...
# ➡ Label: 1, Reason: Both articles discuss the impact of government cuts on public services, with Article 1 focusing on the Conservative Party's proposed tax cuts and thei
#
# ✅ Pair (sim=0.766):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: Mr Kennedy added his party's priorities of free long-term care for the elderly, abolishing top-up fe...
# ➡ Label: 1, Reason: Both articles discuss political positions and proposals related to taxation and public services in the UK, particularly in the context of an upcoming
#
# ✅ Pair (sim=0.760):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: Tory co-chairman Liam Fox has opened proceedings with a speech criticising Tony Blair's record in go...
# ➡ Label: 0, Reason: Both articles discuss political themes related to the Conservative Party and Labour Party in the context of an upcoming election. Article 1 focuses on
#
# ✅ Pair (sim=0.755):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: "First time buyers are being squeezed out of the housing market not only by higher house prices but ...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on political issues related to tax cuts and public services in the context of an election
#
# ✅ Pair (sim=0.753):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: The plan would boost energy conservation, says the party - and insulation could save £100 every year...
# ➡ Label: 0, Reason: Article 1 discusses the political divide between the Conservative and Labour parties regarding tax cuts and public service funding, while Article 2 fo
#
# ✅ Pair (sim=0.752):
# 🔸 Article 1: He said Tory plans to cut £35bn tax would "cut deep into public service"."This will be the central d...
# 🔸 Article 2: But Mr Howard said he rejected the idea that the Tories and BNP appealed to the same voting instinct...
# ➡ Label: 0, Reason: Article 1 discusses the Conservative Party's proposed tax cuts and their impact on public services, contrasting it with Labour's investment plans. Art
#
# ✅ Pair (sim=0.795):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: The value of trade in April-July rose to $186.3m (£97m) from $64.4m in the same period in 2003, the ...
# ➡ Label: 0, Reason: Article 1 discusses the FAO's recommendations for liberalizing trade to benefit developing countries, focusing on trade barriers and subsidies affecti
#
# ✅ Pair (sim=0.776):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: Industrial output rose 2.1% - adjusted for the time of year - in January from a month earlier.Weaker...
# ➡ Label: 0, Reason: Article 1 discusses trade liberalization, the impact of trade barriers and subsidies on developing countries, and the agricultural market, while Artic
#
# ✅ Pair (sim=0.774):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: "[The unemployment figures] show the main problem of the French economy: we have growth but without ...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on trade liberalization and its impact on developing countries, particularly in the conte
#
# ✅ Pair (sim=0.763):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: The plan would boost energy conservation, says the party - and insulation could save £100 every year...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on trade liberalization and its impact on developing countries, specifically in
#
# ✅ Pair (sim=0.761):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: Women will be employed in Saudi Arabia's foreign ministry for the first time this year, Foreign Mini...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on trade liberalization and the impact of trade barriers on developing countries
#
# ✅ Pair (sim=0.751):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: Mortgage lending rose by £7.1bn in December, up from a £6.4bn rise in November.Changes to mortgage r...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on trade liberalization and agricultural markets, particularly in developing cou
#
# ✅ Pair (sim=0.748):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: The European Parliament has thrown out a bill that would have allowed software to be patented.To bec...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on trade liberalization and the impact of trade barriers on developing countries
#
# ✅ Pair (sim=0.748):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: The owner of the technology-dominated Nasdaq stock index plans to sell shares to the public and list...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on trade liberalization and the impact of trade barriers on developing countries
#
# ✅ Pair (sim=0.743):
# 🔸 Article 1: The FAO has urged the World Trade Organisation to swiftly conclude negotiations to liberalise trade,...
# 🔸 Article 2: "Members of the joint venture including Contrack are committed to the ongoing reconstruction efforts...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on trade liberalization and agricultural markets, particularly the impact of tra
#
# ✅ Pair (sim=0.765):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: Commentators say that a deal with Euronext, which owns the Liffe derivatives exchange in London and ...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on Mitsubishi Motors and its negotiations with PSA Peugeot Citroen regarding a potential
#
# ✅ Pair (sim=0.760):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: Russian oil company Yukos has dropped the threat of legal action against five banks it had accused o...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on Mitsubishi Motors and its potential alliance with PSA Peugeot Citroen, highli
#
# ✅ Pair (sim=0.753):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: The Football Association will take no action against Chelsea boss Jose Mourinho following his sendin...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on Mitsubishi Motors and its potential alliance with PSA Peugeot Citroen, highli
#
# ✅ Pair (sim=0.750):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: He told Czech newspaper Daily Sport: "I don't know why I didn't play on Sunday.Baros, who is Liverpo...
# ➡ Label: 0, Reason: The two articles discuss completely different topics. Article 1 focuses on Mitsubishi Motors and its negotiations with PSA Peugeot Citroen regarding a
#
# ✅ Pair (sim=0.746):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: Tory co-chairman Liam Fox has opened proceedings with a speech criticising Tony Blair's record in go...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on Mitsubishi Motors and its negotiations with PSA Peugeot Citroen, highlighting
#
# ✅ Pair (sim=0.745):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: David Beckham expressed his relief at Real Madrid's passage to the Champions League knockout phase.B...
# ➡ Label: 0, Reason: The two articles discuss completely different topics. Article 1 focuses on Mitsubishi Motors and its potential alliance with PSA Peugeot Citroen, whil
#
# ✅ Pair (sim=0.742):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: The company should now be able put this dispute behind it, with the departure of Mr Camus and with t...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on Mitsubishi Motors and its negotiations with PSA Peugeot Citroen regarding a possible a
#
# ✅ Pair (sim=0.741):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: England will protest to the International Rugby Board (IRB) about the referee's performance in the d...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on Mitsubishi Motors and its potential alliance with PSA Peugeot Citroen, while
#
# ✅ Pair (sim=0.739):
# 🔸 Article 1: Trouble-hit Mitsubishi Motors is in talks with French carmaker PSA Peugeot Citroen about a possible ...
# 🔸 Article 2: Ronaldo refused to commit his long-term future to the club.I'm happy but nobody knows the future.""T...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on Mitsubishi Motors and its negotiations with PSA Peugeot Citroen regarding a p
#
# ✅ Pair (sim=0.799):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: Microsoft is investigating a trojan program that attempts to switch off the firm's anti-spyware soft...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on piracy and copyright infringement related to a peer-to-peer network, while Article 2 a
#
# ✅ Pair (sim=0.791):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: T-Mobile confirmed that the US Secret Service was also looking into whether the hacker accessed phot...
# ➡ Label: 0, Reason: Article 1 discusses a case of piracy involving a peer-to-peer network and copyright infringement, while Article 2 focuses on a hacking incident involv
#
# ✅ Pair (sim=0.784):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: "Members of the joint venture including Contrack are committed to the ongoing reconstruction efforts...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal case involving piracy and copyright infringement in the context of pe
#
# ✅ Pair (sim=0.772):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: Amit Yoran was director of the National Cyber Security Division within the US Department of Homeland...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on a piracy case involving the US Department of Justice and peer-to-peer networks, specif
#
# ✅ Pair (sim=0.771):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: It has filed 100 lawsuits against operators of BitTorrent server sites since December.In BitTorrent ...
# ➡ Label: 1, Reason: Both articles discuss legal actions related to piracy and peer-to-peer networks. Article 1 focuses on the prosecution of individuals involved in a pir
#
# ✅ Pair (sim=0.765):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: The US movie industry has launched legal action to sue people who facilitate illegal film downloadin...
# ➡ Label: 1, Reason: Both articles discuss issues related to copyright infringement and illegal downloading, specifically focusing on peer-to-peer networks and the actions
#
# ✅ Pair (sim=0.762):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: Aaliyah was a rising star in music and film before she was killed.A New York appeals court has told ...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal case involving piracy and copyright infringement related to a peer-to
#
# ✅ Pair (sim=0.760):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: Tory co-chairman Liam Fox has opened proceedings with a speech criticising Tony Blair's record in go...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal case involving piracy and copyright infringement in the context of a
#
# ✅ Pair (sim=0.760):
# 🔸 Article 1: In a statement the US Department of Justice said the two men operated the central hubs in a piracy c...
# 🔸 Article 2: The woman said she was assaulted after a recording of the Jimmy Kimmel Live TV show on the ABC netwo...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal case involving copyright infringement and piracy within a peer-to-pee
#
# ✅ Pair (sim=0.784):
# 🔸 Article 1: The Chicago Film Critics Association (CFCA) named it winner in five categories including best film a...
# 🔸 Article 2: A film that follows a group of alienated youth in a Paris suburb as they prepare to perform an 18th ...
# ➡ Label: 0, Reason: The two articles discuss different films and their respective awards. Article 1 focuses on the film 'Sideways' and its accolades from various film cri
#
# ✅ Pair (sim=0.767):
# 🔸 Article 1: The Chicago Film Critics Association (CFCA) named it winner in five categories including best film a...
# 🔸 Article 2: Actor Michael Douglas is to co-produce and star in an adventure film about a diamond robbery set in ...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on the awards and recognition received by the film 'Sideways' and its cast, while Article
#
# ✅ Pair (sim=0.748):
# 🔸 Article 1: The Chicago Film Critics Association (CFCA) named it winner in five categories including best film a...
# 🔸 Article 2: "You have explored the possibilities of film with an immense talent," Mr de Vabres said as he presen...
# ➡ Label: 0, Reason: The two articles discuss different topics related to film. Article 1 focuses on the awards and recognitions received by the film 'Sideways' and its ca
#
# ✅ Pair (sim=0.747):
# 🔸 Article 1: The Chicago Film Critics Association (CFCA) named it winner in five categories including best film a...
# 🔸 Article 2: US actor Jamie Foxx has been given two nominations for Golden Globe awards, with Meryl Streep, Morga...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on the awards won by the film 'Sideways' and its cast, while Article 2 discusses nominati
#
# ✅ Pair (sim=0.737):
# 🔸 Article 1: The Chicago Film Critics Association (CFCA) named it winner in five categories including best film a...
# 🔸 Article 2: Ray has been nominated in six Oscar categories including best film and best actor for Jamie Foxx.Osc...
# ➡ Label: 0, Reason: The two articles discuss different films, 'Sideways' in Article 1 and 'Ray' in Article 2. While both articles mention awards and nominations related t
#
# ✅ Pair (sim=0.720):
# 🔸 Article 1: The Chicago Film Critics Association (CFCA) named it winner in five categories including best film a...
# 🔸 Article 2: Russian drama The Return (Vozvrashchenie) has been named winner of the BBC Four World Cinema Award.T...
# ➡ Label: 0, Reason: The two articles discuss different films and awards. Article 1 focuses on the film 'Sideways' and its accolades from the Chicago Film Critics Associat
#
# ✅ Pair (sim=0.720):
# 🔸 Article 1: The Chicago Film Critics Association (CFCA) named it winner in five categories including best film a...
# 🔸 Article 2: Director Oliver Stone's historical epic Alexander has failed in its bid to conquer the box office, e...
# ➡ Label: 0, Reason: The two articles discuss different films and their respective critical receptions. Article 1 focuses on the accolades received by the film 'Sideways'
#
# ✅ Pair (sim=0.770):
# 🔸 Article 1: Shares of Sumitomo Mitsui Financial (SMFG), and Daiwa Securities jumped amid speculation that two of...
# 🔸 Article 2: The owner of the technology-dominated Nasdaq stock index plans to sell shares to the public and list...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on the potential merger between two Japanese financial companies, Sumitomo Mitsu
#
# ✅ Pair (sim=0.733):
# 🔸 Article 1: Shares of Sumitomo Mitsui Financial (SMFG), and Daiwa Securities jumped amid speculation that two of...
# 🔸 Article 2: IBM said it had taken the step in response to greater customer demand for the open source software.L...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on the potential merger between two Japanese financial companies, Sumitomo Mitsu
#
# ✅ Pair (sim=0.727):
# 🔸 Article 1: Shares of Sumitomo Mitsui Financial (SMFG), and Daiwa Securities jumped amid speculation that two of...
# 🔸 Article 2: The value of trade in April-July rose to $186.3m (£97m) from $64.4m in the same period in 2003, the ...
# ➡ Label: 0, Reason: Article 1 discusses a potential merger between two Japanese financial companies, Sumitomo Mitsui Financial and Daiwa Securities, focusing on their sto
#
# ✅ Pair (sim=0.725):
# 🔸 Article 1: Shares of Sumitomo Mitsui Financial (SMFG), and Daiwa Securities jumped amid speculation that two of...
# 🔸 Article 2: "Members of the joint venture including Contrack are committed to the ongoing reconstruction efforts...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on the potential merger between two Japanese financial companies, Sumitomo Mitsu
#
# ✅ Pair (sim=0.723):
# 🔸 Article 1: Shares of Sumitomo Mitsui Financial (SMFG), and Daiwa Securities jumped amid speculation that two of...
# 🔸 Article 2: Industrial output rose 2.1% - adjusted for the time of year - in January from a month earlier.Weaker...
# ➡ Label: 0, Reason: Article 1 discusses a potential merger between two financial companies in Japan, focusing on their stock performance and corporate statements. Article
#
# ✅ Pair (sim=0.723):
# 🔸 Article 1: Shares of Sumitomo Mitsui Financial (SMFG), and Daiwa Securities jumped amid speculation that two of...
# 🔸 Article 2: Commentators say that a deal with Euronext, which owns the Liffe derivatives exchange in London and ...
# ➡ Label: 0, Reason: The two articles discuss different financial companies and potential mergers or acquisitions. Article 1 focuses on the speculation surrounding a merge
#
# ✅ Pair (sim=0.719):
# 🔸 Article 1: Shares of Sumitomo Mitsui Financial (SMFG), and Daiwa Securities jumped amid speculation that two of...
# 🔸 Article 2: The owners of Rossignol, the Boix-Vives family, are said to be considering an offer from Quiksilver....
# ➡ Label: 0, Reason: The two articles discuss different companies and industries. Article 1 focuses on a potential merger between Sumitomo Mitsui Financial Group and Daiwa
#
# ✅ Pair (sim=0.867):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: "I think we have taken to Europe really well," said McClaren."I think we played quite well and it wa...
# ➡ Label: 1, Reason: Both articles discuss Middlesbrough's performance in European football, specifically in the context of the UEFA Cup. They mention Steve McClaren's com
#
# ✅ Pair (sim=0.856):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: "Playing for eighth place is good but I miss the Champions League.Anelka, 25, is in talks over a con...
# ➡ Label: 0, Reason: The two articles discuss different aspects of football. Article 1 focuses on a specific UEFA Cup match involving Middlesbrough and their strategy to a
#
# ✅ Pair (sim=0.850):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: He added: "We have had to play two matches in three days which is foreign to many of my players and,...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on a football team's performance in the UEFA Cup and their strategy to avoid stronger opp
#
# ✅ Pair (sim=0.849):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: Kewell, 26, had hoped to play against Fulham last weekend and to be ready for the Champions League t...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on Middlesbrough's performance in the UEFA Cup and their strategy to win their group, whi
#
# ✅ Pair (sim=0.847):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: Italy coach John Kirwan has challenged his side to match the performance they produced in pushing Ir...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on a UEFA Cup match involving Middlesbrough and mentions teams like Lazio, Villarreal, an
#
# ✅ Pair (sim=0.845):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: He told Czech newspaper Daily Sport: "I don't know why I didn't play on Sunday.Baros, who is Liverpo...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on a football team's performance in the UEFA Cup and their strategy for upcoming matches,
#
# ✅ Pair (sim=0.844):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: David Beckham expressed his relief at Real Madrid's passage to the Champions League knockout phase.B...
# ➡ Label: 0, Reason: The two articles discuss different football-related topics. Article 1 focuses on Middlesbrough's performance in the UEFA Cup and their strategy agains
#
# ✅ Pair (sim=0.838):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: Brentford face a home tie against holders Manchester United in the FA Cup sixth round if they can co...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on a UEFA Cup match involving Middlesbrough and mentions teams like Lazio, Villarreal, an
#
# ✅ Pair (sim=0.835):
# 🔸 Article 1: "Winning those two has put us in a great position and it has been a fantastic experience playing the...
# 🔸 Article 2: "It does not look like Pires will be ready for two to three weeks."Ashley Cole has refused to blame ...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on a UEFA Cup match involving Middlesbrough and their opponents, while Article 2 discusse
#
# ✅ Pair (sim=0.858):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: "I'm happy Madrid is interested in me because it has always been my dream since I was little to play...
# ➡ Label: 1, Reason: Both articles discuss players from Arsenal expressing interest in or being linked to Real Madrid. Article 1 focuses on Edu's contract situation and me
#
# ✅ Pair (sim=0.853):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: Ronaldo refused to commit his long-term future to the club.I'm happy but nobody knows the future.""T...
# ➡ Label: 1, Reason: Both articles discuss football players expressing uncertainty about their contract situations and potential interest from other clubs. Article 1 focus
#
# ✅ Pair (sim=0.836):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: And Houllier, away from his brief at Liverpool, has been hugely impressed with the Premiership.Houll...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on Edu's contract situation with Arsenal and potential interest from other clubs, while A
#
# ✅ Pair (sim=0.809):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: Arsenal boss Arsene Wenger says he has no plans to sign a new goalkeeper during the January transfer...
# ➡ Label: 0, Reason: The two articles discuss different topics related to Arsenal Football Club. Article 1 focuses on Edu's contract situation and his potential interest f
#
# ✅ Pair (sim=0.808):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: But Williams said: "I want to make it clear that I'm committed totally to Scottish rugby."I'd like t...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on the contract situation of Arsenal midfielder Edu and his potential transfer i
#
# ✅ Pair (sim=0.806):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: "Playing for eighth place is good but I miss the Champions League.Anelka, 25, is in talks over a con...
# ➡ Label: 1, Reason: Both articles discuss football players expressing their desires regarding contract negotiations and their aspirations for playing at a higher competit
#
# ✅ Pair (sim=0.800):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: Henin-Hardenne slid down the world rankings in the second half of 2004 after contracting the illness...
# ➡ Label: 0, Reason: The two articles discuss completely different topics. Article 1 focuses on the contract situation of football player Edu at Arsenal, while Article 2 d
#
# ✅ Pair (sim=0.796):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: But Beckham revealed that his immediate priority was winning the Spanish league title with Real Madr...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on Arsenal midfielder Edu's contract situation and potential interest from other clubs, i
#
# ✅ Pair (sim=0.783):
# 🔸 Article 1: Last month Wenger said he we was hopeful Edu would sign a new deal and played down suggestions that ...
# 🔸 Article 2: We will see how good France are and the scrum is the key."Gethin [Jenkins] won't be intimidated tomo...
# ➡ Label: 0, Reason: The two articles discuss completely different topics. Article 1 focuses on the contract situation of Arsenal midfielder Edu and his potential transfer
#
# ✅ Pair (sim=0.748):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: Birmingham have confirmed Blackburn made a bid for Robbie Savage - but managing director Karen Brady...
# ➡ Label: 0, Reason: The two articles discuss different subjects. Article 1 focuses on a legal dispute between a footballer and a singer regarding the release of an album,
#
# ✅ Pair (sim=0.740):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: But now he has pulled out with a bruised knee and is likely to be replaced by Carragher, alongside B...
# ➡ Label: 0, Reason: Article 1 discusses a legal dispute between a footballer and a singer regarding the release of an album, while Article 2 focuses on injuries and playe
#
# ✅ Pair (sim=0.723):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: Reid rejected a move to Southampton after Forest accepted a cash-plus-players offer while Spurs had ...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal dispute between a footballer and a singer regarding the release of an
#
# ✅ Pair (sim=0.721):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: Labour has always maintained Mr Brown would have a central campaign role.Work and pensions minister ...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal dispute between a footballer and a singer regarding the release of an
#
# ✅ Pair (sim=0.720):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: Blackburn have said all along that they want £6m for the midfielder and Williams has rejected propos...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal dispute between a footballer and a singer regarding a record label an
#
# ✅ Pair (sim=0.719):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: ''Robbie has an agreement with Larne that he can negotiate with interested clubs.But it would be gre...
# ➡ Label: 0, Reason: The two articles discuss entirely different subjects. Article 1 focuses on a legal dispute between a footballer and a singer regarding the release of
#
# ✅ Pair (sim=0.719):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: But Williams said: "I want to make it clear that I'm committed totally to Scottish rugby."I'd like t...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal dispute between a footballer and an R&B singer regarding the release
#
# ✅ Pair (sim=0.711):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: He told Czech newspaper Daily Sport: "I don't know why I didn't play on Sunday.Baros, who is Liverpo...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal dispute between a footballer and a singer regarding the release of an
#
# ✅ Pair (sim=0.711):
# 🔸 Article 1: Premiership footballer and record company boss Kevin Campbell has gained a court injunction stopping...
# 🔸 Article 2: "It does not look like Pires will be ready for two to three weeks."Ashley Cole has refused to blame ...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal dispute between a footballer and a singer regarding a music album rel
#
# ✅ Pair (sim=0.803):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: Kenteris and Thanou still have to face trial on charges brought separately by Greek prosecutors of m...
# ➡ Label: 1, Reason: Both articles discuss doping scandals in athletics, focusing on athletes facing consequences for doping violations. Article 1 centers on Michelle Coll
#
# ✅ Pair (sim=0.803):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: Thanou, 30, was provisionally suspended for missing a test before the Olympics, but the decision was...
# ➡ Label: 1, Reason: Both articles discuss athletes facing doping-related issues and their appeals or suspensions. Article 1 focuses on Michelle Collins and her appeal aga
#
# ✅ Pair (sim=0.795):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: Greek athletics' governing body has postponed by two weeks the judgement on sprinters Costas Kenteri...
# ➡ Label: 1, Reason: Both articles discuss issues related to doping in athletics, specifically focusing on athletes facing bans due to doping violations. Article 1 centers
#
# ✅ Pair (sim=0.793):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: "I was not counting on this being the end of the day for me.Andre Agassi's involvement in the Austra...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on Michelle Collins and her appeal against a doping ban related to the Balco scandal, whi
#
# ✅ Pair (sim=0.788):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: Kim Clijsters has denied reports that she has pulled out of January's Australian Open because of her...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on a doping scandal involving sprinter Michelle Collins and her appeal against a doping b
#
# ✅ Pair (sim=0.777):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: England will protest to the International Rugby Board (IRB) about the referee's performance in the d...
# ➡ Label: 0, Reason: The two articles discuss completely different topics. Article 1 focuses on a doping scandal involving sprinter Michelle Collins and her appeal against
#
# ✅ Pair (sim=0.772):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: He told Czech newspaper Daily Sport: "I don't know why I didn't play on Sunday.Baros, who is Liverpo...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a doping scandal involving sprinter Michelle Collins and her appeal against a
#
# ✅ Pair (sim=0.767):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: She said the decision by the US Supreme Court to give legal protection to two Britons held at Guanta...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a doping scandal involving sprinter Michelle Collins and her appeal against a
#
# ✅ Pair (sim=0.764):
# 🔸 Article 1: Sprinter Michelle Collins has lodged an appeal against her eight-year doping ban with the North Amer...
# 🔸 Article 2: British team member Hayley Yelling said the team would understand if Radcliffe opted out of the even...
# ➡ Label: 0, Reason: The two articles discuss different topics. Article 1 focuses on Michelle Collins' doping ban and the associated scandal, while Article 2 talks about P
#
# ✅ Pair (sim=0.716):
# 🔸 Article 1: The New York court did not rule on Lee's claims to a share of profits from some Spider-Man and Hulk ...
# 🔸 Article 2: The woman said she was assaulted after a recording of the Jimmy Kimmel Live TV show on the ABC netwo...
# ➡ Label: 0, Reason: The two articles discuss entirely different topics. Article 1 focuses on a legal battle involving Stan Lee and Marvel regarding profits from Spider-Ma
#
# ✅ Pair (sim=0.744):
# 🔸 Article 1: Mr Khodorkovsky handed over his stake after the forced sale of Yukos' core oil production unit, Yuga...
# 🔸 Article 2: Russian oil company Yukos has dropped the threat of legal action against five banks it had accused o...
# ➡ Label: 1, Reason: Both articles discuss the Russian oil company Yukos and its key asset, Yuganskneftegaz. Article 1 focuses on Mikhail Khodorkovsky's transfer of his st
#
# ✅ Pair (sim=0.718):
# ...
# 2025-03-20 04:07:15,630 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 04:07:15,632 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 04:07:15,635 - DEBUG - receive_response_body.complete
# 2025-03-20 04:07:15,636 - DEBUG - response_closed.started
# 2025-03-20 04:07:15,637 - DEBUG - response_closed.complete
# 2025-03-20 04:07:15,638 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Thu, 20 Mar 2025 04:07:15 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-gbgqrr8mnjzeosnimrnxpaf7', 'openai-processing-ms': '1586', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '5000', 'x-ratelimit-limit-tokens': '2000000', 'x-ratelimit-remaining-requests': '4999', 'x-ratelimit-remaining-tokens': '1999663', 'x-ratelimit-reset-requests': '12ms', 'x-ratelimit-reset-tokens': '10ms', 'x-request-id': 'req_0e34e050efcd956e962ebec0773e989b', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '92325767e884ef61-IAD', 'content-encoding': 'br', 'alt-svc': 'h3=":443"; ma=86400'})
# 2025-03-20 04:07:15,639 - DEBUG - request_id: req_0e34e050efcd956e962ebec0773e989b
# 2025-03-20 04:07:15,646 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\nYou are a helpful assistant for text similarity analysis.\nAre these two articles discussing the same topic?\n\nArticle 1: "The song will not be released as a single, but will be played regularly during a Chinese telethon on Friday in aid of victims of the Boxing Day disaster.Performers have yet to be confirmed for NBC\'s aid relief benefit later this month.The United Nations warned that the number killed in the disaster could rise sharply, with aid yet to reach some remote areas.It follows a two-hour telethon carried by all four major US television networks 10 days after the 11 September terror attacks in 2001."\nArticle 2: "He told Czech newspaper Daily Sport: "I don\'t know why I didn\'t play on Sunday.Baros, who is Liverpool\'s leading scorer this season, denied reports of a row with Benitez but claims he is mystified at being left on the bench.And although Baros insisted thoughts of quitting Anfield are "not in my mind right now", he admitted "everything is possible".Baros denied suggestions he wanted to leave the Millennium Stadium before the match upon learning of his omission from the starting line-up."\n\nProvide your reasoning and output in strict JSON format:\n{\n  "reasoning": "Explain your decision briefly",\n  "answer": "Yes" or "No"\n}'}], 'model': 'gpt-4o-mini', 'max_tokens': 300, 'temperature': 0.2}}
# 2025-03-20 04:07:15,648 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 04:07:15,649 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-03-20 04:07:15,650 - DEBUG - send_request_headers.complete
# 2025-03-20 04:07:15,652 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-03-20 04:07:17,366 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 04:07:17 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'1596'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1999682'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'9ms'), (b'x-request-id', b'req_31af78e0ea2f986624b1eb124a260337'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'92325772d89aef61-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 04:07:17,367 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 04:07:17,368 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 04:07:17,372 - DEBUG - receive_response_body.complete
# 2025-03-20 04:07:17,373 - DEBUG - response_closed.started
# 2025-03-20 04:07:17,374 - DEBUG - response_closed.complete
# 2025-03-20 04:07:17,375 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Thu, 20 Mar 2025 04:07:17 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-gbgqrr8mnjzeosnimrnxpaf7', 'openai-processing-ms': '1596', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '5000', 'x-ratelimit-limit-tokens': '2000000', 'x-ratelimit-remaining-requests': '4999', 'x-ratelimit-remaining-tokens': '1999682', 'x-ratelimit-reset-requests': '12ms', 'x-ratelimit-reset-tokens': '9ms', 'x-request-id': 'req_31af78e0ea2f986624b1eb124a260337', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '92325772d89aef61-IAD', 'content-encoding': 'br', 'alt-svc': 'h3=":443"; ma=86400'})
# 2025-03-20 04:07:17,376 - DEBUG - request_id: req_31af78e0ea2f986624b1eb124a260337
# 2025-03-20 04:07:17,383 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\nYou are a helpful assistant for text similarity analysis.\nAre these two articles discussing the same topic?\n\nArticle 1: "The song will not be released as a single, but will be played regularly during a Chinese telethon on Friday in aid of victims of the Boxing Day disaster.Performers have yet to be confirmed for NBC\'s aid relief benefit later this month.The United Nations warned that the number killed in the disaster could rise sharply, with aid yet to reach some remote areas.It follows a two-hour telethon carried by all four major US television networks 10 days after the 11 September terror attacks in 2001."\nArticle 2: "She said the decision by the US Supreme Court to give legal protection to two Britons held at Guantanamo Bay was a significant victory for human rights and the international rule of law.It said she was not expressing political opinions.But Downing Street said she was speaking in her capacity as a lawyer.Mrs Blair\'s remarks are said to have been made in a speech to law students in Massachusetts.BBC news correspondent Gary O\'Donoghue said Mrs Blair was likely to face further calls for restraint, since the US election is imminent.The prime minister\'s wife is said to have praised the Supreme Court for overruling the White House on the legal rights of Guantanamo Bay detainees."\n\nProvide your reasoning and output in strict JSON format:\n{\n  "reasoning": "Explain your decision briefly",\n  "answer": "Yes" or "No"\n}'}], 'model': 'gpt-4o-mini', 'max_tokens': 300, 'temperature': 0.2}}
# 2025-03-20 04:07:21,562 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 04:07:21 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'1556'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1999679'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'9ms'), (b'x-request-id', b'req_88bcfce3adcb9c186765e97132654f3e'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9232578d5cc6ef61-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 04:07:31,603 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 04:07:31 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'1490'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1999582'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'12ms'), (b'x-request-id', b'req_8cdc7d17e4c9a97f5438312a4d66bee5'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'923257cb3af0ef61-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 04:07:31,605 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 04:07:36,439 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 04:07:36 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'1084'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1999617'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'11ms'), (b'x-request-id', b'req_78e8382a22590f68410c0df33de4e2dc'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'923257ec5c48ef61-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 04:07:36,441 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 04:07:36,443 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 04:07:36,444 - DEBUG - receive_response_body.complete
# 2025-03-20 04:07:36,445 - DEBUG - response_closed.started
# 2025-03-20 04:07:36,446 - DEBUG - response_closed.complete
# 2025-03-20 04:07:36,447 - DEBUG - HTTP Response: POST https://api.openai.com/v1/chat/completions "200 OK" Headers({'date': 'Thu, 20 Mar 2025 04:07:36 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-organization': 'user-gbgqrr8mnjzeosnimrnxpaf7', 'openai-processing-ms': '1084', 'openai-version': '2020-10-01', 'x-ratelimit-limit-requests': '5000', 'x-ratelimit-limit-tokens': '2000000', 'x-ratelimit-remaining-requests': '4999', 'x-ratelimit-remaining-tokens': '1999617', 'x-ratelimit-reset-requests': '12ms', 'x-ratelimit-reset-tokens': '11ms', 'x-request-id': 'req_78e8382a22590f68410c0df33de4e2dc', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '923257ec5c48ef61-IAD', 'content-encoding': 'br', 'alt-svc': 'h3=":443"; ma=86400'})
# 2025-03-20 04:07:36,448 - DEBUG - request_id: req_78e8382a22590f68410c0df33de4e2dc
# 2025-03-20 04:07:36,456 - DEBUG - Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'user', 'content': '\nYou are a helpful assistant for text similarity analysis.\nAre these two articles discussing the same topic?\n\nArticle 1: ""Mock elections can play an extremely valuable role in helping young people understand how the democratic process works and why it matters," he said.Michael Rafferty, who is mock elections project manager at the Hansard Society, said he looked forward to seeing schools and colleges across the UK participating in the mock votes.The Y Vote initiative is being run jointly by the Electoral Commission, the Hansard Society and the Department for Education and Skills in the run-up to local elections and the general election, possibly on 5 May.Mock elections are planned to take place in schools across the UK."\nArticle 2: "Mr Walkington said he wanted the party to be ready for any "mischief" rivals or the media tried to throw at it."I also know the party will be put under scrutiny in the media and from the other parties as never before - and we will need to show ourselves ready and prepared to counter the mischief and misrepresentation that all too often comes from the party\'s opponents.The Lib Dems have appointed a senior figure from BT to be the party\'s new communications chief for their next general election effort.Party chief executive Lord Rennard said the appointment was a "significant strengthening of the Lib Dem team"."\n\nProvide your reasoning and output in strict JSON format:\n{\n  "reasoning": "Explain your decision briefly",\n  "answer": "Yes" or "No"\n}'}], 'model': 'gpt-4o-mini', 'max_tokens': 300, 'temperature': 0.2}}
# 2025-03-20 04:07:36,458 - DEBUG - Sending HTTP Request: POST https://api.openai.com/v1/chat/completions
# 2025-03-20 04:07:41,656 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 20 Mar 2025 04:07:41 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-gbgqrr8mnjzeosnimrnxpaf7'), (b'openai-processing-ms', b'1126'), (b'openai-version', b'2020-10-01'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'2000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'1999572'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'12ms'), (b'x-request-id', b'req_31d407ad881f9d3da327666fe8008e61'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9232580d7b8eef61-IAD'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# 2025-03-20 04:07:41,657 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-03-20 04:07:41,658 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-03-20 04:07:41,660 - DEBUG - receive_response_body.complete
# 2025-03-20 04:07:41,661 - DEBUG - response_closed.started
